# %%
import requests
import datetime

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)
# Out:
# https://newsapi.org/v2/everything?q=AI&from=2025-10-29&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en

# %%
import pandas as pd

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)

# %%
call
# Out:
# <Response [200]>

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
# Out:
# [{'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Robert Ginsburg, Contributor, \n Robert Ginsburg, Contributor\n https://www.forbes.com/sites/robertginsburg/',
#   'title': 'Two Faces Of Freedom: Why Liberalism Needs A Reboot In The Age Of AI',
#   'description': 'To be economically liberal is to favor low taxes and minimal government; to be politically liberal is to favor social programs and collective protections.',
#   'url': 'https://www.forbes.com/sites/robertginsburg/2025/10/23/two-faces-of-freedom-why-liberalism-needs-a-reboot-in-the-age-of-ai/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/68fa7a182e59bb46db48f88f/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2025-10-23T18:58:10Z',
# ...

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict)

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict)
pip install newspaper3k
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict)
pip install newspaper3k


pip install lxml_html_clean
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict)
pip install newspaper3k


pip install lxml_html_clean 

df= pd.DataFrame(master_data)

df.rename(columns={'publishedAt':'date_created'},inplace= True)
df['source'] = df['source'].apply(lambda x: x['name'] if pd.notna(x) and 'name' in x else None)

from newspaper import Article, Config
def full_content(url):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
    config = Config()
    config.browser_user_agent = user_agent
    page = Article(url, config = config)

    try:
        page.download()
        page.parse()
        return page.text
    except Exception as e:
        print(f"Error retrieving content from {url}: {e}")
        return 'couldnt retrieve'
df['content'] = df['url'].apply(full_content)
# Out:
# Error retrieving content from https://cryptoslate.com/trump-tariff-short-trader-who-made-200m-correctly-predicts-binances-cz-pardon/: Article `download()` failed with 403 Client Error: Forbidden for url: https://cryptoslate.com/trump-tariff-short-trader-who-made-200m-correctly-predicts-binances-cz-pardon/ on URL https://cryptoslate.com/trump-tariff-short-trader-who-made-200m-correctly-predicts-binances-cz-pardon/

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict)
pip install newspaper3k


pip install lxml_html_clean 

df= pd.DataFrame(master_data)

df.rename(columns={'publishedAt':'date_created'},inplace= True)
df['source'] = df['source'].apply(lambda x: x['name'] if pd.notna(x) and 'name' in x else None)

from newspaper import Article, Config
def full_content(url):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
    config = Config()
    config.browser_user_agent = user_agent
    page = Article(url, config = config)

    try:
        page.download()
        page.parse()
        return page.text
    except Exception as e:
        print(f"Error retrieving content from {url}: {e}")
        return 'couldnt retrieve'
df['content'] = df['url'].apply(full_content)

df['content'] = df['content'].str.replace('\n', ' ')
df = df[df['content'] != 'couldnt retrieve']

# %%
df
# Out:
#                                                author  \
# 0   Robert Ginsburg, Contributor, \n Robert Ginsbu...
# 1                      development.dinnovos@gmail.com
# 2                                                None
# 3                                                None
# 4                                         Michael Kan
# ..                                                ...
# 93                                       Muskan Singh
# 94                                    Frank Landymore
# 95                                            wsj.com
# 96                                      bloomberg.com
# 97                                           cnbc.com
#
#                                                 title              source  \
# 0   Two Faces Of Freedom: Why Liberalism Needs A R...              Forbes
# 1                                dinnovos-agent 0.5.2            Pypi.org
# 2                          mithridatium added to PyPI            Pypi.org
# ...

# %%
pip install newspaper3k

pip install lxml_html_clean

# %%
import requests
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()

# Calculate yesterday's date
yesterday = today - timedelta(days=1)

# Print yesterday's date
#print("Yesterday's date:", yesterday)
url = f"https://newsapi.org/v2/everything?q=AI&from={yesterday}&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en"
print(url)

call=requests.get(url)
data=call.json()
data['articles']
master_data = []
for i in data['articles']:
    main_dict = {
            'author' : i['author'],
            'title' : i['title'] ,
            'source' : i['source'],
            'url' : i['url'],
             'publishedAt': i['publishedAt']
                }
    master_data.append(main_dict) 

df= pd.DataFrame(master_data)

df.rename(columns={'publishedAt':'date_created'},inplace= True)
df['source'] = df['source'].apply(lambda x: x['name'] if pd.notna(x) and 'name' in x else None)

from newspaper import Article, Config
def full_content(url):
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
    config = Config()
    config.browser_user_agent = user_agent
    page = Article(url, config = config)

    try:
        page.download()
        page.parse()
        return page.text
    except Exception as e:
        print(f"Error retrieving content from {url}: {e}")
        return 'couldnt retrieve'
df['content'] = df['url'].apply(full_content)

df['content'] = df['content'].str.replace('\n', ' ')
df = df[df['content'] != 'couldnt retrieve']


import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd


# Download required NLTK datasets
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('all')

# Function to count words excluding stopwords
def count_words_without_stopwords(text):
    if isinstance(text, (str, bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return len(filtered_words)
    else:
        return 0

# Sentiment analysis setup
sid = SentimentIntensityAnalyzer()

def get_sentiment(text):
    sentiment_scores = sid.polarity_scores(text)
    print(sentiment_scores)
    compound_score = sentiment_scores['compound']
    print(compound_score)
    if compound_score >= 0.05:
        sentiment = 'Positive'
    elif compound_score <= -0.05:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'
    return sentiment, compound_score
df[['Sentiment', 'Compound_Score']] = df['content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))
df['word_count'] = df['content'].apply(count_words_without_stopwords)


df
# Out:
# https://newsapi.org/v2/everything?q=AI&from=2025-10-29&sortBy=publishedAt&apiKey=bb58a6058bf44744a1397f06aed27b15&language=en
# Error retrieving content from https://www.sspnet.org/community/news/new-wiley-guidelines-give-researchers-clear-path-forward-in-responsible-ai-use/: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.sspnet.org/community/news/new-wiley-guidelines-give-researchers-clear-path-forward-in-responsible-ai-use/ on URL https://www.sspnet.org/community/news/new-wiley-guidelines-give-researchers-clear-path-forward-in-responsible-ai-use/
# ...

# %%
dataframe = extract_transform_function(df)
print(dataframe.head())
# Out:
#                                               author  \
# 0  Robert Ginsburg, Contributor, \n Robert Ginsbu...
# 1                     development.dinnovos@gmail.com
# 2                                               None
# 3                                               None
# 4                                        Michael Kan
#
#                                                title     source  \
# 0  Two Faces Of Freedom: Why Liberalism Needs A R...     Forbes
# 1                               dinnovos-agent 0.5.2   Pypi.org
# 2                         mithridatium added to PyPI   Pypi.org
# 3                                 mithridatium 0.1.0   Pypi.org
# 4  Former Director at US Hacking Tool Provider Ma...  PCMag.com
#
#                                                  url          date_created  \
# 0  https://www.forbes.com/sites/robertginsburg/20...  2025-10-23T18:58:10Z
# 1     https://pypi.org/project/dinnovos-agent/0.5.2/  2025-10-23T18:57:30Z
# ...

# %%
df_spark = spark.createDataFrame(master_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_spark = spark.createDataFrame(master_data)
#
# NameError: name 'spark' is not defined

# %%
df_spark.printSchema()
# Out:
# root
#  |-- author: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- urlToImage: string (nullable = true)

# %%
df_spark.select('author','title').show()
# Out:
# +--------------------+--------------------+
# |              author|               title|
# +--------------------+--------------------+
# |            ABC News|Newly released Ep...|
# |news@ixbt.com (Da...|Учёные разработал...|
# |                NULL|Onko tässä maailm...|
# |         electrek.co|Tesla complains a...|
# |news@ixbt.com (Da...|Kia запускает Plu...|
# |          Jiří Filip|Kdo ovládne autom...|
# |       Katie Collins|Is EV Charging Re...|
# |Jacob Shamsian,Ka...|Newly released Ep...|
# |        La Rédaction|Le nom d’Elon Mus...|
# |        Fred Lambert|Podcast: Tesla de...|
# |    Matthew Mountjoy|New Tesla notific...|
# |          Brian Wang|NVIDIA CEO Jensen...|
# |   Katherine Donlevy|Elon Musk was sch...|
# |        gagadget.com|Китай вводит эксп...|
# |       Piyush Shukla|Dark secrets and ...|
# |      Gandharv Walia|Did Celeste Rivas...|
# |          Matt Novak|Newly Released Ep...|
# |                NULL|Elon Musk en prin...|
# ...

# %%
df_spark.filter(df_spark.Author).show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_spark.filter(df_spark.title).show()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pyspark/sql/classic/dataframe.py:1012, in DataFrame.filter(self, condition)
#    1010     jdf = self._jdf.filter(condition)
#    1011 elif isinstance(condition, Column):
# -> 1012     jdf = self._jdf.filter(condition._jc)
#    1013 else:
#    1014     raise PySparkTypeError(
#    1015         errorClass="NOT_COLUMN_OR_STR",
#    1016         messageParameters={"arg_name": "condition", "arg_type": type(condition).__name__},
#    1017     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
# ...
